# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

# %%
plt.plot(lista, listb)
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb)
plt.title("thursday graph", fontsize=15, color="red")
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb)
plt.title("thursday graph", fontsize=15, color="red")
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 125

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb)
plt.title("thursday graph", fontsize=15, color="red")
plt.show()

# %%
# ?plt.plot

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb, "--r")
plt.title("thursday graph")
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb, "Dg")
plt.plot(lista, listb, "--r")
plt.title("thursday graph")
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb, "Dg")
plt.plot(lista, listb, "--r")

plt.xlim(0, 5)
plt.ylim(0, 50)

plt.title("thursday graph")
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]

plt.plot(lista, listb, "Dg")
plt.plot(lista, listb, "--r")

plt.xlim(0, 5)
plt.ylim(0, 50)

plt.xlabel("days")
plt.ylabel("temperature")

plt.title("thursday graph")
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]
listc = [15, 22, 39, 45]

plt.plot(lista, listb, "Dg")
plt.plot(lista, listb, "--r")

plt.plot(lista, listc, "ob")
plt.plot(lista, listc, "-y")


plt.xlabel("days")
plt.ylabel("temperature")

plt.title("thursday graph")
plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]
listc = [15, 22, 39, 45]

plt.plot(lista, listb, "Dg", label="collage points")
plt.plot(lista, listb, "--r", label="wed data")

plt.plot(lista, listc, "ob")
plt.plot(lista, listc, "-y", label="thu data")


plt.xlabel("days")
plt.ylabel("temperature")

plt.title("thursday graph")

plt.legend()

plt.show()

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]
listc = [15, 22, 39, 45]

plt.plot(lista, listb, "Dg", label="collage points")
plt.plot(lista, listb, "--r", label="wed data")

plt.plot(lista, listc, "ob")
plt.plot(lista, listc, "-y", label="thu data")


plt.xlabel("days")
plt.ylabel("temperature")

plt.title("thursday graph")

plt.legend()
plt.savefig("wed_thu.png", transparent=True)

plt.show()

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the axes.
#
#     Call signatures::
#
#         legend()
#         legend(labels)
#         legend(handles, labels)
#
#     The call signatures correspond to three different ways how to use
#     this method.
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         line, = ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
#     Specific lines can be excluded from the automatic legend element
# ...

# %%
lista = [1, 2, 3, 4]
listb = [20, 15, 38, 45]
listc = [15, 22, 39, 45]

# row=2 col=2 


plt.subplot(221)
plt.plot(lista, listb)

plt.subplot(224)
plt.plot(lista, listc)

plt.show()

# %%
lista = [1, 2, 3, 4, 5, 6, 7, 8, 9]
listb = [20, 15, 38, 45, 33, 56, 78, 12, 40]
listc = [15, 22, 39, 45]

plt.bar(lista, listb)

plt.title("thursday plot")
plt.ylabel("some units")

plt.show()

# %%
lista = [1, 2, 3, 4, 5, 6, 7, 8, 9]
listb = [20, 15, 38, 45, 33, 56, 78, 12, 40]
listc = [15, 22, 39, 45]

plt.bar(lista, listb, color="pink", edgecolor='red')

plt.title("thursday plot")
plt.ylabel("some units")

plt.show()

# %%
lista = [1, 2, 3, 4, 5, 6, 7]

listb = [20, 15, 38, 45, 33, 56, 78]
listc = ["mon", "tue", "wed", "thu", 'fri', "sat", "sun"]

plt.pie(listb, labels=listc)

plt.title("daily plot")

plt.show()

# %%
lista = [1, 2, 3, 4, 5, 6, 7]

listb = [20, 15, 38, 45, 33, 56, 78]
listc = ["mon", "tue", "wed", "thu", 'fri', "sat", "sun"]
e = [0.1, 0, 0, 0, 0.3, 0, 0]

plt.pie(listb, labels=listc, explode=e, autopct='%1.2f%%')

plt.title("daily plot")

plt.show()

# %%
lista = [1, 2, 3, 4, 5, 6, 7]

listb = [20, 15, 38, 45, 33, 56, 78]
listc = ["mon", "tue", "wed", "thu", 'fri', "sat", "sun"]
e = [0.1, 0, 0, 0, 0.3, 0, 0]


plt.figure(figsize=(8,8))
plt.pie(listb, labels=listc, explode=e, autopct='%1.2f%%', shadow=True)

plt.title("daily plot")

plt.legend(loc='upper left')

plt.show()

# %%
dfa = pd.read_csv("data.csv")

# %%
dfa
# Out:
#           name  age     gender      planet  level  rating
# 0       anakin   23       male    tatooine     10       1
# 1       amilyn   45     female  resistance      7       3
# 2         jawa   10  humanoids  everywhere      2       6
# 3         luke   40       male     alderin      9       1
# 4      obi-wan   34       male     alderin      8       2
# 5         leia   20     female     alderin      9       3
# 6    boba fett   50       male  everywhere      7       5
# 7  mandalorian   45       male  everywhere      8       2
# 8         yoda  156       male  everywhere      9       2

# %%
dfa['age']
# Out:
# 0     23
# 1     45
# 2     10
# 3     40
# 4     34
# 5     20
# 6     50
# 7     45
# 8    156
# Name: age, dtype: int64

# %%
plt.bar(dfa['name'], dfa['age'])
plt.show()

# %%
plt.barh(dfa['name'], dfa['age'])
plt.show()

# %%
dfa.plot(kind='barh', x='name', y='age')
plt.show()

# %%
list(dfa.columns)
# Out:
# ['name', 'age', 'gender', 'planet', 'level', 'rating']

# %%
axis = plt.gca() #get current axis
dfa.plot(x='name', y='level', ax=axis)
dfa.plot(x='name', y='rating', ax=axis)
plt.show()

# %%
dfa.plot(kind='scatter', x='level', y='rating')
plt.show()

# %%
dfa
# Out:
#           name  age     gender      planet  level  rating
# 0       anakin   23       male    tatooine     10       1
# 1       amilyn   45     female  resistance      7       3
# 2         jawa   10  humanoids  everywhere      2       6
# 3         luke   40       male     alderin      9       1
# 4      obi-wan   34       male     alderin      8       2
# 5         leia   20     female     alderin      9       3
# 6    boba fett   50       male  everywhere      7       5
# 7  mandalorian   45       male  everywhere      8       2
# 8         yoda  156       male  everywhere      9       2

# %%
dfa.groupby('planet')['name'].nunique()
# Out:
# planet
# alderin       3
# everywhere    4
# resistance    1
# tatooine      1
# Name: name, dtype: int64

# %%
dfa.groupby('planet')['name'].nunique().plot(kind='bar')
plt.show()

# %%
dfa.groupby(['planet', 'gender']).size().unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
dfa.groupby(['planet', 'gender']).size()
# Out:
# planet      gender
# alderin     female       1
#             male         2
# everywhere  humanoids    1
#             male         3
# resistance  female       1
# tatooine    male         1
# dtype: int64

# %%
dfa.groupby(['planet', 'gender']).size().unstack()
# Out:
# gender      female  humanoids  male
# planet
# alderin        1.0        NaN   2.0
# everywhere     NaN        1.0   3.0
# resistance     1.0        NaN   NaN
# tatooine       NaN        NaN   1.0
