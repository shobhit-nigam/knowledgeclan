# %%
path = "https://raw.githubusercontent.com/shobhit-nigam/knowledgeclan/main/datasets/nba_2013.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# point gaurds

# %%
dfa = pd.read_csv(path)

# %%
dfa
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0        Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1      Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2       Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3     Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4     Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# ..              ...  ..  ...          ...  ..  ..   ...  ...   ...    ...
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      ...  drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0    ...  144  216   28   23   26   30  122   171  2013-2014        2013
# 1    ...  190  332   43   40   57   71  203   265  2013-2014        2013
# 2    ...  204  306   38   24   36   39  108   362  2013-2014        2013
# 3    ...  230  262  248   35    3  146  136  1330  2013-2014        2013
# 4    ...  183  277   40   23   46   63  187   328  2013-2014        2013
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...        ...         ...
# 476  ...  159  228  217   78   16  204  151   939  2013-2014        2013
# 477  ...  137  166   95   46   12   95  156  1144  2013-2014        2013
# 478  ...  310  476  182  167   36  165  213  1417  2013-2014        2013
# 479  ...  235  353   92   40   41   87  170   490  2013-2014        2013
# 480  ...  179  282   36   18   38   60  137   399  2013-2014        2013
#
# [481 rows x 31 columns]

# %%
dfa["pos"].value_counts()
# Out:
# SG    109
# SF     99
# PF     96
# C      90
# PG     85
# F       1
# G       1
# Name: pos, dtype: int64

# %%
point_gaurds = dfa[dfa['pos'] == 'PG']

# %%
point_gaurds['ppg'] = point_gaurds['pts']/point_gaurds['g']
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
point_gaurds
# Out:
#                 player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  \
# 24       D.J. Augustin  PG   26          TOT  71   9  1939  298  718  0.415
# 29     Leandro Barbosa  PG   31          PHO  20   0   368   56  131  0.427
# 30          Jose Barea  PG   29          MIN  79   1  1471  254  656  0.387
# 38      Jerryd Bayless  PG   25          TOT  72  19  1686  248  617  0.402
# 50         Steve Blake  PG   33          TOT  55  28  1498  133  353  0.377
# ..                 ...  ..  ...          ...  ..  ..   ...  ...  ...    ...
# 459  Russell Westbrook  PG   25          OKC  46  46  1412  346  791  0.437
# 462     Deron Williams  PG   29          BRK  64  58  2059  322  716  0.450
# 465     Louis Williams  PG   27          ATL  60   7  1445  197  493  0.400
# 467        Mo Williams  PG   31          POR  74   0  1834  280  672  0.417
# 471       Nate Wolters  PG   22          MIL  58  31  1309  170  389  0.437
#
#      ...  trb  ast  stl  blk  tov   pf   pts     season  season_end        ppg
# 24   ...  130  313   53    3  125  147   930  2013-2014        2013  13.098592
# 29   ...   37   32    7    4   19   30   150  2013-2014        2013   7.500000
# 30   ...  154  303   26    0  125  129   660  2013-2014        2013   8.354430
# 38   ...  145  194   60    9   82  161   666  2013-2014        2013   9.250000
# 50   ...  159  307   54    8  102   85   378  2013-2014        2013   6.872727
# ..   ...  ...  ...  ...  ...  ...  ...   ...        ...         ...        ...
# 459  ...  263  319   88    7  177  104  1002  2013-2014        2013  21.782609
# 462  ...  168  392   93   13  143  148   915  2013-2014        2013  14.296875
# 465  ...  124  210   45    4   92   65   625  2013-2014        2013  10.416667
# 467  ...  153  321   55   10  149  197   721  2013-2014        2013   9.743243
# 471  ...  149  187   35   15   57   67   417  2013-2014        2013   7.189655
#
# [85 rows x 32 columns]

# %%
# assists & total turnovers

# %%
point_gaurds = point_gaurds[point_gaurds['tov'] != 0]

# %%
point_gaurds['atr'] = point_gaurds['ast']/point_gaurds['tov']
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=[10, 8])
plt.scatter(point_gaurds['ppg'], point_gaurds['atr'])
plt.title("point gaurds")
plt.xlabel("points per game")
plt.ylabel("assist turnover ratio")
plt.show()

# %%
# centroid based clustering 

# k in k-means

# %%
# step 1 --> assign points to clusters 
# step 2 --> update new centroids of the clusters

# %%
num_clusters = 5

random_initial_points = np.random.choice(point_gaurds.index, size=num_clusters)

# %%
centroids = point_gaurds.loc[random_initial_points]

# %%
plt.figure(figsize=[10, 8])
plt.scatter(point_gaurds['ppg'], point_gaurds['atr'])
plt.scatter(centroids['ppg'], centroids['atr'])
plt.title("centroids")
plt.xlabel("points per game")
plt.ylabel("assist turnover ratio")
plt.show()

# %%
# key = cluster_id 
# value = centroid's coords expressed as list [ppg, atr]

# %%
def centroids_to_dict(centroids):
    dictc = {}
    counter = 0
    
    for index, row in centroids.iterrows():
        coord = [row['ppg'], row['atr']]
        dictc[counter] = coord
        counter = counter + 1
        
    return dictc

# %%
centroids_dict = centroids_to_dict(centroids)

# %%
def calculate_distance(centroid, player_values):
    root_distance = 0
    
    for x in range(len(centroid)):
        difference = centroid[x] - player_values[x] 
        squared_difference = difference**2
        root_distance += squared_difference
        
    euclid_distance = math.sqrt(root_distance)
    return euclid_distance

# %%
def assign_to_cluster(row):
    lowest_distance = None
    closest_cluster = None
    
    for cluster_id , centroid in centroids_dict.items():
        df_row = [ row['ppg'], row['atr']]
        euclidean_distance = calculate_distance(centroid, df_row)
        
        if lowest_distance is None:
            lowest_distance = euclidean_distance
            closest_cluster = cluster_id
        elif euclidean_distance < lowest_distance:
            lowest_distance = euclidean_distance
            closest_cluster = cluster_id
    return closest_cluster

# %%
point_gaurds['cluster'] = point_gaurds.apply(lambda row: assign_to_cluster(row), axis=1)
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def visualize_clusters(df, num_clusters):
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    
    for n in range(num_clusters):
        clustered_df = df[df['cluster']==n]
        plt.scatter(clustered_df['ppg'], clustered_df['atr'], c=colors[n-1])
        plt.xlabel('points per game')
        plt.ylabel("assist turnover ratio")
    plt.show()

# %%
visualize_clusters(point_gaurds, 5)

# %%
def recalculate_centroids(df):
    new_centroids_dict = {}
    
    for cluster_id in range(0, num_clusters):
        values_in_cluster = df[df['cluster'] == cluster_id] 
        
        new_centroid = [np.average(values_in_cluster['ppg']), np.average(values_in_cluster['atr'])]
        new_centroids_dict[cluster_id] = new_centroid
        
    return new_centroids_dict

# %%
centroids_dict = recalculate_centroids(point_gaurds)

# %%
point_gaurds['cluster'] = point_gaurds.apply(lambda row: assign_to_cluster(row), axis=1)

visualize_clusters(point_gaurds, 5)
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
centroids_dict = recalculate_centroids(point_gaurds)

point_gaurds['cluster'] = point_gaurds.apply(lambda row: assign_to_cluster(row), axis=1)

visualize_clusters(point_gaurds, 5)
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
centroids_dict = recalculate_centroids(point_gaurds)

point_gaurds['cluster'] = point_gaurds.apply(lambda row: assign_to_cluster(row), axis=1)

visualize_clusters(point_gaurds, 5)
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(point_gaurds[['ppg', 'atr']])

point_gaurds['cluster'] = kmeans.labels_

visualize_clusters(point_gaurds, num_clusters)
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
point_gaurds
# Out:
#                 player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  \
# 24       D.J. Augustin  PG   26          TOT  71   9  1939  298  718  0.415
# 29     Leandro Barbosa  PG   31          PHO  20   0   368   56  131  0.427
# 30          Jose Barea  PG   29          MIN  79   1  1471  254  656  0.387
# 38      Jerryd Bayless  PG   25          TOT  72  19  1686  248  617  0.402
# 50         Steve Blake  PG   33          TOT  55  28  1498  133  353  0.377
# ..                 ...  ..  ...          ...  ..  ..   ...  ...  ...    ...
# 459  Russell Westbrook  PG   25          OKC  46  46  1412  346  791  0.437
# 462     Deron Williams  PG   29          BRK  64  58  2059  322  716  0.450
# 465     Louis Williams  PG   27          ATL  60   7  1445  197  493  0.400
# 467        Mo Williams  PG   31          POR  74   0  1834  280  672  0.417
# 471       Nate Wolters  PG   22          MIL  58  31  1309  170  389  0.437
#
#      ...  stl  blk  tov   pf   pts     season  season_end        ppg  \
# 24   ...   53    3  125  147   930  2013-2014        2013  13.098592
# 29   ...    7    4   19   30   150  2013-2014        2013   7.500000
# 30   ...   26    0  125  129   660  2013-2014        2013   8.354430
# 38   ...   60    9   82  161   666  2013-2014        2013   9.250000
# 50   ...   54    8  102   85   378  2013-2014        2013   6.872727
# ..   ...  ...  ...  ...  ...   ...        ...         ...        ...
# 459  ...   88    7  177  104  1002  2013-2014        2013  21.782609
# 462  ...   93   13  143  148   915  2013-2014        2013  14.296875
# 465  ...   45    4   92   65   625  2013-2014        2013  10.416667
# 467  ...   55   10  149  197   721  2013-2014        2013   9.743243
# 471  ...   35   15   57   67   417  2013-2014        2013   7.189655
#
#           atr  cluster
# 24   2.504000        4
# 29   1.684211        0
# 30   2.424000        0
# 38   2.365854        0
# 50   3.009804        0
# ..        ...      ...
# 459  1.802260        3
# 462  2.741259        4
# 465  2.282609        0
# 467  2.154362        0
# 471  3.280702        0
#
# [82 rows x 34 columns]

# %%
point_gaurds['cluster'].value_counts()
# Out:
# 0    27
# 2    24
# 1    13
# 4    12
# 3     6
# Name: cluster, dtype: int64

# %%
point_gaurds[ point_gaurds['cluster'] == 0 ]
# Out:
#                player pos  age bref_team_id   g  gs    mp   fg  fga    fg.  \
# 29    Leandro Barbosa  PG   31          PHO  20   0   368   56  131  0.427
# 30         Jose Barea  PG   29          MIN  79   1  1471  254  656  0.387
# 38     Jerryd Bayless  PG   25          TOT  72  19  1686  248  617  0.402
# 50        Steve Blake  PG   33          TOT  55  28  1498  133  353  0.377
# 64       Aaron Brooks  PG   29          TOT  72  12  1557  233  581  0.401
# 78         Will Bynum  PG   31          DET  56   3  1054  184  430  0.428
# 87     Mario Chalmers  PG   27          MIA  73  73  2178  254  560  0.454
# 95        Norris Cole  PG   25          MIA  82   6  2014  207  500  0.414
# 142     Jordan Farmar  PG   27          LAL  41   5   912  151  364  0.415
# 146    Raymond Felton  PG   29          NYK  65  65  2017  240  608  0.395
# 189      Devin Harris  PG   30          DAL  40   0   818   96  254  0.378
# 204       George Hill  PG   27          IND  76  76  2434  272  616  0.442
# 207      Kirk Hinrich  PG   33          CHI  73  61  2116  243  619  0.393
# 220      Jarrett Jack  PG   30          CLE  80  31  2252  286  698  0.410
# 274  Shaun Livingston  PG   28          BRK  76  54  1974  235  487  0.483
# 280      Shelvin Mack  PG   23          ATL  73  11  1490  209  501  0.417
# 283  Kendall Marshall  PG   22          LAL  54  45  1564  170  419  0.406
# 293      Ray McCallum  PG   22          SAC  45  10   897  113  300  0.377
# 306     Patrick Mills  PG   25          SAS  81   2  1527  309  666  0.464
# 325        Steve Nash  PG   39          LAL  15  10   313   36   94  0.383
# 371     Brian Roberts  PG   28          NOP  72  42  1667  244  581  0.420
# 372     Nate Robinson  PG   29          DEN  44   1   866  164  383  0.428
# 377       Ricky Rubio  PG   23          MIN  82  82  2638  255  670  0.381
# 454       C.J. Watson  PG   29          IND  63   5  1193  146  334  0.437
# 465    Louis Williams  PG   27          ATL  60   7  1445  197  493  0.400
# 467       Mo Williams  PG   31          POR  74   0  1834  280  672  0.417
# 471      Nate Wolters  PG   22          MIL  58  31  1309  170  389  0.437
#
#      ...  stl  blk  tov   pf  pts     season  season_end        ppg       atr  \
# 29   ...    7    4   19   30  150  2013-2014        2013   7.500000  1.684211
# 30   ...   26    0  125  129  660  2013-2014        2013   8.354430  2.424000
# 38   ...   60    9   82  161  666  2013-2014        2013   9.250000  2.365854
# 50   ...   54    8  102   85  378  2013-2014        2013   6.872727  3.009804
# 64   ...   52   13  117  146  645  2013-2014        2013   8.958333  1.991453
# 78   ...   39    7  103  121  485  2013-2014        2013   8.660714  2.097087
# 87   ...  119   16  162  210  716  2013-2014        2013   9.808219  2.203704
# 95   ...   77    5  127  156  527  2013-2014        2013   6.426829  1.952756
# 142  ...   38    8   95   65  416  2013-2014        2013  10.146341  2.094737
# 146  ...   78   27  129  157  630  2013-2014        2013   9.692308  2.829457
# 189  ...   28    2   59   72  315  2013-2014        2013   7.875000  3.016949
# 204  ...   75   23   92  158  781  2013-2014        2013  10.276316  2.880435
# 207  ...   80   26  120  203  666  2013-2014        2013   9.123288  2.383333
# 220  ...   56   22  133  133  760  2013-2014        2013   9.500000  2.436090
# 274  ...   93   31  105  172  629  2013-2014        2013   8.276316  2.333333
# 280  ...   50    2   89  100  544  2013-2014        2013   7.452055  3.044944
# 283  ...   48    4  150   76  430  2013-2014        2013   7.962963  3.180000
# 293  ...   22    9   39   69  280  2013-2014        2013   6.222222  3.076923
# 306  ...   68    9   63  114  826  2013-2014        2013  10.197531  2.365079
# 325  ...    7    2   31   18  102  2013-2014        2013   6.800000  2.774194
# 371  ...   43    7   95  132  677  2013-2014        2013   9.402778  2.463158
# 372  ...   36    4   58   92  457  2013-2014        2013  10.386364  1.931034
# 377  ...  191   11  221  218  781  2013-2014        2013   9.524390  3.185520
# 454  ...   60    8   60   66  414  2013-2014        2013   6.571429  1.783333
# 465  ...   45    4   92   65  625  2013-2014        2013  10.416667  2.282609
# 467  ...   55   10  149  197  721  2013-2014        2013   9.743243  2.154362
# 471  ...   35   15   57   67  417  2013-2014        2013   7.189655  3.280702
#
#      cluster
# 29         0
# 30         0
# 38         0
# 50         0
# 64         0
# 78         0
# 87         0
# 95         0
# 142        0
# 146        0
# 189        0
# 204        0
# 207        0
# 220        0
# 274        0
# 280        0
# 283        0
# 293        0
# 306        0
# 325        0
# 371        0
# 372        0
# 377        0
# 454        0
# 465        0
# 467        0
# 471        0
#
# [27 rows x 34 columns]
