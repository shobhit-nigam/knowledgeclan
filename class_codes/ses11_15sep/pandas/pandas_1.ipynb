# %%
import pandas as pd

# %%
dfa = pd.read_csv('effects.csv')

# %%
dfa
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
dfa.head(7)
# Out:
#   Direction  Year        Date    Weekday Country Commodity Transport_Mode  \
# 0   Exports  2015  01/01/2015   Thursday     All       All            All
# 1   Exports  2015  02/01/2015     Friday     All       All            All
# 2   Exports  2015  03/01/2015   Saturday     All       All            All
# 3   Exports  2015  04/01/2015     Sunday     All       All            All
# 4   Exports  2015  05/01/2015     Monday     All       All            All
# 5   Exports  2015  06/01/2015    Tuesday     All       All            All
# 6   Exports  2015  07/01/2015  Wednesday     All       All            All
#
#   Measure      Value  Cumulative
# 0       $  104000000   104000000
# 1       $   96000000   200000000
# 2       $   61000000   262000000
# 3       $   74000000   336000000
# 4       $  105000000   442000000
# 5       $   76000000   518000000
# 6       $   59000000   577000000

# %%
dfa.columns
# Out:
# Index(['Direction', 'Year', 'Date', 'Weekday', 'Country', 'Commodity',
#        'Transport_Mode', 'Measure', 'Value', 'Cumulative'],
#       dtype='object')

# %%
list(dfa.columns)
# Out:
# ['Direction',
#  'Year',
#  'Date',
#  'Weekday',
#  'Country',
#  'Commodity',
#  'Transport_Mode',
#  'Measure',
#  'Value',
#  'Cumulative']

# %%
dfa[ dfa['Weekday'] == 'Thursday' ]
# Out:
#         Direction  Year        Date   Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015  Thursday     All       All
# 7         Exports  2015  08/01/2015  Thursday     All       All
# 14        Exports  2015  15/01/2015  Thursday     All       All
# 21        Exports  2015  22/01/2015  Thursday     All       All
# 28        Exports  2015  29/01/2015  Thursday     All       All
# ...           ...   ...         ...       ...     ...       ...
# 111403  Reimports  2021  11/11/2021  Thursday     All       All
# 111410  Reimports  2021  18/11/2021  Thursday     All       All
# 111417  Reimports  2021  25/11/2021  Thursday     All       All
# 111424  Reimports  2021  02/12/2021  Thursday     All       All
# 111431  Reimports  2021  09/12/2021  Thursday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 7                 All       $  111000000   688000000
# ...

# %%
dfa[ dfa['Value'] > 10000000 ]
# Out:
#        Direction  Year        Date    Weekday Country  \
# 0        Exports  2015  01/01/2015   Thursday     All
# 1        Exports  2015  02/01/2015     Friday     All
# 2        Exports  2015  03/01/2015   Saturday     All
# 3        Exports  2015  04/01/2015     Sunday     All
# 4        Exports  2015  05/01/2015     Monday     All
# ...          ...   ...         ...        ...     ...
# 111087   Imports  2021  11/12/2021   Saturday     All
# 111088   Imports  2021  12/12/2021     Sunday     All
# 111089   Imports  2021  13/12/2021     Monday     All
# 111090   Imports  2021  14/12/2021    Tuesday     All
# 111091   Imports  2021  15/12/2021  Wednesday     All
#
#                           Commodity Transport_Mode Measure      Value  \
# 0                               All            All       $  104000000
# 1                               All            All       $   96000000
# 2                               All            All       $   61000000
# ...

# %%
dfa[ (dfa['Weekday'] == 'Thursday') & (dfa['Value'] > 10000000) ]
# Out:
#        Direction  Year        Date   Weekday Country  \
# 0        Exports  2015  01/01/2015  Thursday     All
# 7        Exports  2015  08/01/2015  Thursday     All
# 14       Exports  2015  15/01/2015  Thursday     All
# 21       Exports  2015  22/01/2015  Thursday     All
# 28       Exports  2015  29/01/2015  Thursday     All
# ...          ...   ...         ...       ...     ...
# 111057   Imports  2021  11/11/2021  Thursday     All
# 111064   Imports  2021  18/11/2021  Thursday     All
# 111071   Imports  2021  25/11/2021  Thursday     All
# 111078   Imports  2021  02/12/2021  Thursday     All
# 111085   Imports  2021  09/12/2021  Thursday     All
#
#                           Commodity Transport_Mode Measure      Value  \
# 0                               All            All       $  104000000
# 7                               All            All       $  111000000
# 14                              All            All       $  109000000
# ...

# %%
dfb = dfa[ (dfa['Weekday'] == 'Thursday') & (dfa['Value'] > 10000000) ]

# %%
dfb['Value']
# Out:
#        Direction  Year        Date   Weekday Country  \
# 0        Exports  2015  01/01/2015  Thursday     All
# 7        Exports  2015  08/01/2015  Thursday     All
# 14       Exports  2015  15/01/2015  Thursday     All
# 21       Exports  2015  22/01/2015  Thursday     All
# 28       Exports  2015  29/01/2015  Thursday     All
# ...          ...   ...         ...       ...     ...
# 111057   Imports  2021  11/11/2021  Thursday     All
# 111064   Imports  2021  18/11/2021  Thursday     All
# 111071   Imports  2021  25/11/2021  Thursday     All
# 111078   Imports  2021  02/12/2021  Thursday     All
# 111085   Imports  2021  09/12/2021  Thursday     All
#
#                           Commodity Transport_Mode Measure      Value  \
# 0                               All            All       $  104000000
# 7                               All            All       $  111000000
# 14                              All            All       $  109000000
# ...

# %%
dfb['Value'].mean()
# Out:
# 65023742.660199136

# %%
dfa['Weekday'].nunique()
# Out:
# 7

# %%
dfa['Weekday'].unique()
# Out:
# array(['Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday'], dtype=object)

# %%
dfa['Weekday'].value_counts()
# Out:
# Friday       15959
# Tuesday      15934
# Monday       15931
# Sunday       15925
# Thursday     15919
# Wednesday    15897
# Saturday     15873
# Name: Weekday, dtype: int64

# %%
x = 10
y = 20

# %%
x == y
# Out:
# False

# %%
dfb
# Out:
#        Direction  Year        Date   Weekday Country  \
# 0        Exports  2015  01/01/2015  Thursday     All
# 7        Exports  2015  08/01/2015  Thursday     All
# 14       Exports  2015  15/01/2015  Thursday     All
# 21       Exports  2015  22/01/2015  Thursday     All
# 28       Exports  2015  29/01/2015  Thursday     All
# ...          ...   ...         ...       ...     ...
# 111057   Imports  2021  11/11/2021  Thursday     All
# 111064   Imports  2021  18/11/2021  Thursday     All
# 111071   Imports  2021  25/11/2021  Thursday     All
# 111078   Imports  2021  02/12/2021  Thursday     All
# 111085   Imports  2021  09/12/2021  Thursday     All
#
#                           Commodity Transport_Mode Measure      Value  \
# 0                               All            All       $  104000000
# 7                               All            All       $  111000000
# 14                              All            All       $  109000000
# ...

# %%
dfb.to_excel("thursdays_10000000.xlsx", index=False)

# %%
dfb.to_excel("thursdays_10000000.xlsx")
